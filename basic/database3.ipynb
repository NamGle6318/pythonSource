# %% [markdown]
# # Mongodb 연동
# 1. pip install pymongo

# %%
from pymongo import MongoClient
import certifi

# client = MongoClient("mongodb+srv://test:ko4jMHzBdQAKZdwx@cluster0.klmy4jb.mongodb.net/") # MongoDB Compass code 삽입

client = MongoClient(
    "mongodb+srv://test:ko4jMHzBdQAKZdwx@ac-n7fvtwq-shard-00-00.klmy4jb.mongodb.net/",
    tlsCAFile=certifi.where(),
)
db = client["sample_mflix"]  # db

movies = db.movies
users = db.users


document = users.find_one({"name": "Hong"})

print(document)
for doc in document:
    print(doc, doc)
# Out:
# {'_id': ObjectId('6848eb2b03060b09ce30ca7d'), 'name': 'Hong', 'email': 'hong@gmail.com', 'password': '1q2w3e4r1!!!'}
# _id _id
# name name
# email email
# password password

# %%
# 전체 collections 가져오기

collections = db.list_collection_names()

for col in collections:
    print(col)
# Out:
# embedded_movies
# users
# comments
# movies
# sessions
# theaters

# %%
# 전체 collection에서 movies 가져오기
movies = db.movies

# %%
# 영화 상영 시간이 100분 이상인 영화
# {runtime:{&gte:100}}

document = movies.find_one({"runtime":{"$gte":100}})
document
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[59], line 4
#       1 # 영화 상영 시간이 100분 이상인 영화
#       2 # {runtime:{&gte:100}}
# ----> 4 document = movies.find_one({"runtime":{"$gte":100}})
#       5 document
#
# File c:\source\pythonSource\venv\Lib\site-packages\pymongo\synchronous\collection.py:1755, in Collection.find_one(self, filter, *args, **kwargs)
#    1753     filter = {"_id": filter}
#    1754 cursor = self.find(filter, *args, **kwargs)
# -> 1755 for result in cursor.limit(-1):
#    1756     return result
#    1757 return None
#
# File c:\source\pythonSource\venv\Lib\site-packages\pymongo\synchronous\cursor.py:1284, in Cursor.__next__(self)
#    1283 def __next__(self) -> _DocumentType:
# -> 1284     return self.next()
#
# File c:\source\pythonSource\venv\Lib\site-packages\pymongo\synchronous\cursor.py:1260, in Cursor.next(self)
#    1258 if self._empty:
# ...

# %%
document = movies.find_one({"contries":"USA", "imdb.rating":{"$gte":7}})
for doc in document:
    print(doc)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 document = movies.find_one({"contries":"USA", "imdb.rating":{"$gte":7}})
#       2 for doc in document:
#       3     print(doc)
#
# File c:\source\pythonSource\venv\Lib\site-packages\pymongo\synchronous\collection.py:1755, in Collection.find_one(self, filter, *args, **kwargs)
#    1753     filter = {"_id": filter}
#    1754 cursor = self.find(filter, *args, **kwargs)
# -> 1755 for result in cursor.limit(-1):
#    1756     return result
#    1757 return None
#
# File c:\source\pythonSource\venv\Lib\site-packages\pymongo\synchronous\cursor.py:1284, in Cursor.__next__(self)
#    1283 def __next__(self) -> _DocumentType:
# -> 1284     return self.next()
#
# File c:\source\pythonSource\venv\Lib\site-packages\pymongo\synchronous\cursor.py:1260, in Cursor.next(self)
#    1258 if self._empty:
# ...

# %%
# users 컬렉션 가져온 후 이름이 Hong 인 User 조회
# client = MongoClient("mongodb+srv://test:ko4jMHzBdQAKZdwx@cluster0.klmy4jb.mongodb.net/") # MongoDB Compass code 삽입

db = client["sample_mflix"] # db 

users = db.users

document = users.find_one({"name":"Hong"})

print(document)
# Out:
# {'_id': ObjectId('6848eb2b03060b09ce30ca7d'), 'name': 'Hong', 'email': 'hong@gmail.com', 'password': '1q2w3e4r1!!!'}

# %%
# 전체 collections 가져오기

collections = db.list_collection_names()

for col in collections:
    print(col)
# Out:
# embedded_movies
# users
# comments
# movies
# sessions
# theaters

# %%
# 
filter = {"title" : "Regeneration"}
update = {
    "$set": {
        "year":1901
    }
}
result = movies.update_one(filter,update)
print(result.modified_count)
# Out:
# 1

# %%
# delete

result = movies.delete_one({"cast":"A.C. Abadie"})
print(result.deleted_count)
# Out:
# 1

# %%
# delete

result = movies.delete_many({"genres":"History"})
print(result.deleted_count)
# Out:
# 874

# %%
data = {
    "name":"KFC",
    "email":"kfckfc@gmail.com",
    "password":"12q2w31324wer"
}
result = users.insert_one(data)
print(result)
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# Cell In[80], line 6
#       1 data = {
#       2     "name":"KFC",
#       3     "email":"kfckfc@gmail.com",
#       4     "password":"12q2w31324wer"
#       5 }
# ----> 6 result = users.insert_one(data)
#       7 print(result)
#
# File c:\source\pythonSource\venv\Lib\site-packages\pymongo\synchronous\collection.py:891, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     887     document["_id"] = ObjectId()  # type: ignore[index]
#     889 write_concern = self._write_concern_for(session)
#     890 return InsertOneResult(
# --> 891     self._insert_one(
#     892         document,
#     893         ordered=True,
#     894         write_concern=write_concern,
#     895         op_id=None,
#     896         bypass_doc_val=bypass_document_validation,
#     897         session=session,
# ...

# %%
datas = [
    {
    "name":"mon",
    "email":"mon@gmail.com",
    "password":"1234kjasd9fa8sd23"
},
    {
    "name":"daddy",
    "email":"daddy@gmail.com",
    "password":"asdkmxzcvclxzkf234234"
},
    {
    "name":"uncle",
    "email":"uncle@gmail.com",
    "password":"asdlk12431m3dsdvzxcv"
},
    {
    "name":"son",
    "email":"superson@gmail.com",
    "password":"xczvmcxvm12312ewdqawsedq1w2"
},
]
result = users.insert_many(datas)
print(result.inserted_ids)
# Out:
# [ObjectId('6848fd49af518f849e8acdf1'), ObjectId('6848fd49af518f849e8acdf2'), ObjectId('6848fd49af518f849e8acdf3'), ObjectId('6848fd49af518f849e8acdf4')]
