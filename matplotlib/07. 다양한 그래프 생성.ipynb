# %% [markdown]
# ### 1) 막대차트(기본)

# %%
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ><b>색상</b>

# %%
# Out:
# <BarContainer object of 3 artists>

# %%
# Out:
# <BarContainer object of 3 artists>

# %%
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ><b>축 레이블 조정</b>

# %%
# Out:
# (175.0, 190.0)

# %% [markdown]
# ><b>막대 너비 조정</b>

# %%
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ><b>축 레이블 rotation 설정</b>

# %% [markdown]
# ><b>막대 </b>

# %%
# Out:
# ([<matplotlib.axis.XTick at 0x2918574e790>,
#   <matplotlib.axis.XTick at 0x2918574e760>,
#   <matplotlib.axis.XTick at 0x2918572af40>],
#  [Text(0.0, 0, '1번학생'), Text(1.0, 0, '2번학생'), Text(2.0, 0, '3번학생')])

# %% [markdown]
# ### 2) 막대차트(심화)

# %% [markdown]
# **수평막대**

# %%
# Out:
# <BarContainer object of 3 artists>

# %%
# Out:
# (170.0, 195.0)

# %% [markdown]
# **막대 패턴**(https://matplotlib.org/stable/gallery/shapes_and_collections/hatch_style_reference.html)
