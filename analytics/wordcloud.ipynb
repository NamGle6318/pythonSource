# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Using cached wordcloud-1.9.4-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\source\pythonsource\venv\lib\site-packages (from wordcloud) (2.3.1)
# Requirement already satisfied: pillow in c:\source\pythonsource\venv\lib\site-packages (from wordcloud) (11.2.1)
# Requirement already satisfied: matplotlib in c:\source\pythonsource\venv\lib\site-packages (from wordcloud) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\source\pythonsource\venv\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\source\pythonsource\venv\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\source\pythonsource\venv\lib\site-packages (from matplotlib->wordcloud) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\source\pythonsource\venv\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\source\pythonsource\venv\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\source\pythonsource\venv\lib\site-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\source\pythonsource\venv\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\source\pythonsource\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Using cached wordcloud-1.9.4-cp313-cp313-win_amd64.whl (300 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib
import pandas as pd
from wordcloud import WordCloud

# %%
text = 'square'

wc = WordCloud(background_color='white', repeat=True)
wc.generate(text)

plt.figure(figsize=(10,6))
plt.axis('off')
plt.imshow(wc, interpolation='bilinear')
plt.show()

# %%
with open("./data/alice.txt") as f:
    text = f.read()

wc = WordCloud(background_color='white', repeat=True)
wc.generate(text)

plt.figure(figsize=(10,6))
plt.axis('off')
plt.imshow(wc, interpolation='bilinear')
plt.show()

# %%
from PIL import Image
import numpy as np

with open("./data/alice.txt") as f:
    text = f.read()


# 마스크 이미지 가져오기
alice_mask = np.array(Image.open("./data/alice_mask.png"))
    

wc = WordCloud(background_color='white', repeat=True, mask=alice_mask)
wc.generate(text)

plt.figure(figsize=(10,6))
plt.axis('off')
plt.imshow(wc, interpolation='bilinear')
plt.show()
