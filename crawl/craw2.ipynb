# %%
import requests

url = "https://openapi.naver.com/v1/search/book.json"

headers = {
    "X-Naver-Client-Id": "29eMCk9y4aWU3O3bL1o8",
    "X-Naver-Client-Secret": "DclMBxQvY6",
}

params = {"query": "자기계발", "display": 100}

res = requests.get(url, params=params, headers=headers).json()

res_items = res["items"]

book_infos = []
for item in res_items:
    # print(item["title"])
    # print(item["author"])
    # print(item["discount"])
    # print(item["pubdate"])
    no = 1
    book_details = [
        no,
        item["title"],
        item["author"],
        item["discount"],
        item["pubdate"],
        item["description"],
    ]
    no += 1
    book_infos.append(book_details)

print(type(book_infos[0]))
print(book_infos[0:3])
# for book_info in book_infos:
#     print("=====")
#     for book_detail in book_details.values():
#         print(book_detail)
#         print("=====")
# Out:
# <class 'dict'>
# ...

# %%
# 파일 저장
# 1. .csv 저장

import csv

with open("./books.csv", "w", encoding="utf-8", newline="") as f:
    wt = csv.writer(f)
    for book_detail in book_infos:
        key = book_detail.keys()
        value = book_detail.values()
        # wt.writerow(f"{key} : {value}")

# %%
import requests

url = "https://openapi.naver.com/v1/search/book.json"

headers = {
    "X-Naver-Client-Id": "29eMCk9y4aWU3O3bL1o8",
    "X-Naver-Client-Secret": "DclMBxQvY6",
}

params = {
    "query" : "자기계발",
    "display" : 100
}

res = requests.get(url, params=params, headers=headers).json()

res_items = res["items"]

book_infos = []
for item in res_items:
    # print(item["title"])
    # print(item["author"])
    # print(item["discount"])
    # print(item["pubdate"])
    no = 1
    book_details = {
        "id" : no,
        "title":item["title"],
        "author":item["author"],
        "discount":item["discount"],
        "pubdate":item["pubdate"],
        "description":item["description"],
    }
    no += 1
    book_infos.append(book_details)

    print(book_details)
# Out:
# {'id': 1, 'title': '누구도 대신 살아 주지 않는다 (작은 실천으로 원하는 삶에 다가가는 법)', 'author': '브라이언 트레이시', 'discount': '15120', 'pubdate': '20250611', 'description': '평범함에 좌절하지 말라, 당신도 할 수 있다\n누구도 대체 불가능한 성공의 주인공으로 이끌\n브라이언 트레이시의 마스터 클래스\n\n흙수저 고교 중퇴자에서 자수성가의 아이콘으로\n500만 명의 운명을 뒤바꾼 명강의 최신판\n당신의 새로운 미래를 보증하는 성공의 백지수표\n\n\n자수성가의 아이콘으로서 전 세계에 성공의 비결을 전파하는 브라이언 트레이시, 그에게도 ‘흙수저 출신의 저학력자’라는 과거가 있었다. 그는 스물셋이 되기 전까지 형편도, 손에 쥔 것도 변변치 않아 작은 호텔의 접시닦이를 하다 이곳저곳을 떠돌며 막일도 불사했었다. 그랬던 그가 어떻게 자수성가의 아이콘으로 거듭날 수 있었을까? 그 답은 인생에 대한 ‘자기 책임’에 있었다. 이토록 작은 것이 그의 인생에 큰 변화를 불러일으킨 것이다.\n누구나가 그렇듯 인생은 단 한 번뿐이다. 이에 브라이언 트레이시는 성공을 통한 행복이 곧 삶에 대한 책임이라고 말한다. 그 책임을 발휘하는 방법은 발전, 특히 타의가 아닌 자신의 의지를 따른 것이어야 한다. 누구나 이 사실을 알고는 있지만, 망설임은 멈출 길이 없다. 이에 그는 어린 시절에 각인된 억압과 강박도 그 원인이 될 수 있겠지만, 자신의 목표과 가치관을 모르기에 두려움과 망설임이 생겨난다고 답한다. 결국 나를 아는 것이 성공으로 향하는 여정의 시작이라고 할 수 있겠다.\n《누구도 인생을 대신 살아 주지 않는다》에서는 아무도 넘볼 수 없으며, 쉽게 무너지지 않는 강력한 성공의 비결을 소개한다. 브라이언 트레이시는 이 책을 통해 잠재력과 목표, 시간 관리를 비롯하여 전략적 사고, 통찰력과 자제력을 끌어올림으로써 평범한 사람이라도 성공을 이루는 방법의 다각적인 측면을 설명한다. 그러니 우리가 비범한
# ...

# %%
from pymongo import MongoClient

client = MongoClient("mongodb+srv://test:ko4jMHzBdQAKZdwx@cluster0.klmy4jb.mongodb.net/")

db = client['test'] # 컬렉션 가져오기
books = db.books # DB 가져오기

# books.insert_many(book_infos)

# %%
import requests
from openpyxl import Workbook, load_workbook
import re

# 1. naver open api로 쇼핑 검색결과 요청하기
# 2. 받은 결과를 엑셀에 저장하기

# 엑셀파일 생성
wb = Workbook()  # 엑셀파일 생성

ws = wb.active  # 첫번째 sheet 가져오기

ws.title = "Naver_Shopping"  # 시트명 변경

ws.append(["번호", "상품명", "가격", "주소"])
# 셀 너비 조절
ws.column_dimensions["B"].width = 100
ws.column_dimensions["D"].width = 75


url = "https://openapi.naver.com/v1/search/shop.json"

headers = {
    "X-Naver-Client-Id": "29eMCk9y4aWU3O3bL1o8",
    "X-Naver-Client-Secret": "DclMBxQvY6",
}

params = {
    "query": "마우스",
}

res = requests.get(url, params=params, headers=headers).json()  # shopping 목록 요청

shopping_items = res["items"]
no = 1
for item in shopping_items:
    title = re.sub(r"<.*?>", "", item['title'])
    print(title)
    print(item["lprice"])
    print(item["link"])
    ws.append([no, title, item["lprice"], item["link"]])
    no += 1


wb.save("./data/naver_shopping.xlsx")  # 엑셀파일 저장
wb.close()
# Out:
# 로지텍 무선마우스 G304 LIGHTSPEED 무선 게이밍마우스 롤 배그 블랙 병행
# 42000
# https://smartstore.naver.com/main/products/4882707794
# VXE R1 SE+
# 19900
# https://search.shopping.naver.com/catalog/55130347282
# 로지텍 로지텍G PRO X SUPERLIGHT 2 게이밍 마우스 블랙
# 185000
# https://search.shopping.naver.com/catalog/52649143883
# 로지텍G G304 LIGHTSPEED 게이밍 마우스 블랙
# 35960
# https://search.shopping.naver.com/catalog/52649215257
# 로지텍 MX MASTER 3S 그래파이트
# 138990
# https://search.shopping.naver.com/catalog/52648750882
# 로지텍 MX Anywhere 3S 그래파이트
# 94500
# https://search.shopping.naver.com/catalog/52649430184
# 지클릭커 르캄프2 초경량 듀얼 8K 게이밍 마우스 OP200 화이트
# 69640
# https://search.shopping.naver.com/catalog/53686328148
# 지클릭커 쓸떼많은 다쿠아즈 무소음 무선 블루투스 마우스 화이트
# 14900
# https://search.shopping.naver.com/catalog/52649590934
# 지클릭커 버티컬 도톰쉬폰 무소음 인체공학 블루투스 무선 마우스 OP50 그린
# 24800
# https://search.shopping.naver.com/catalog/52798284940
# 로지텍 M331 무소음 블랙
# 24200
# https://search.shopping.naver.com/catalog/52649066849

# %%
## data_kr 엑셀파일의 첫번째 시트를 열어서 가져오기
# 이름 / 주민번호 / 나이 / 성별
# 주민번호를 읽어와서 뒷자리를 *로 바꾸기

from openpyxl import Workbook, load_workbook


wb = load_workbook("./data/sample2.xlsx")
ws = wb.active

for row in ws.iter_rows():
    # print(row)
    print(row[1].value)
# Out:
# 56
# 0
# 87
# 76
# 68
# 7
# 18
# 3
# 83
# 83

# %%
wb = load_workbook("./data/data_kr.xlsx")
ws = wb.active

villager_code = [] # 주민번호 입력받을 리스트

# 엑셀파일의 주민번호 열 받아오기
for row in ws.iter_rows():
    villager_code.append(row[1].value)


new_code = [] # 주민번호 뒷자리 암호화한 거 받아올 리스트

# 주민번호 암호화
for code in villager_code:
    if re.match(r"(\d{6})-(\d{7})", code):
        new_code.append(re.sub(r"\d{7}","*******" , code))

next = 0
# 파일에 주민번호 암호화한걸 입력하기
for i in range(2, len(villager_code) + 1):
    ws["B" + str(i)] = new_code[next]
    next += 1

wb.save("./data/data_kr.xlsx")
wb.close()

# %%
wb = load_workbook("./data/train.xlsx")
ws = wb.active

pattern = re.compile(" Mr\. ")

# 제목 행 제거
for each_row in ws.iter_rows(min_row=2):
    name = each_row[3].value
    result = pattern.search(name)
    if result != None:
        if result.group().strip() == "Mr.":
            print(name)            

wb.close()
# Out:
# Braund, Mr. Owen Harris
# Allen, Mr. William Henry
# Moran, Mr. James
# McCarthy, Mr. Timothy J
# Saundercock, Mr. William Henry
# Andersson, Mr. Anders Johan
# Williams, Mr. Charles Eugene
# Fynney, Mr. Joseph J
# Beesley, Mr. Lawrence
# Sloper, Mr. William Thompson
# Emir, Mr. Farred Chehab
# Fortune, Mr. Charles Alexander
# Todoroff, Mr. Lalio
# Wheadon, Mr. Edward H
# Meyer, Mr. Edgar Joseph
# Holverson, Mr. Alexander Oskar
# Mamee, Mr. Hanna
# Cann, Mr. Ernest Charles
# Kraeff, Mr. Theodor
# Rogers, Mr. William John
# Lennon, Mr. Denis
# Samaan, Mr. Youssef
# Nosworthy, Mr. Richard Cater
# Ostby, Mr. Engelhart Cornelius
# Woolner, Mr. Hugh
# Novel, Mr. Mansouer
# Sirayanian, Mr. Orsen
# Harris, Mr. Henry Birkhardt
# Stewart, Mr. Albert A
# Crease, Mr. Ernest James
# Kink, Mr. Vincenz
# Jenkin, Mr. Stephen Curnow
# Hood, Mr. Ambrose Jr
# Chronopoulos, Mr. Apostolos
# Bing, Mr. Lee
# Moen, Mr. Sigurd Hansen
# Staneff, Mr. Ivan
# Moutal, Mr. Rahamin Haim
# Waelens, Mr. Achille
# ...

# %%
from openpyxl import Workbook, load_workbook

# Mr. / Miss. / Mrs. / 없는 경우

# 이름을 읽어서 새로운 액셀파일 생성
# 남성(Mr.), 미혼여성(Miss.), 기혼여성(Mrs. ), 기타(other ), 시트 생성

wb = load_workbook("./data/train.xlsx")
ws = wb.active

work_book = Workbook()
# 첫번째 시트 가져오기
work_sheet_man = work_book.active
work_sheet_man.title = "남성"

# 두번째 시트 생성
work_sheet_woman = work_book.create_sheet()
work_sheet_woman.title = "기혼녀"

# 세번째 시트 생성
work_sheet_solo_woman = work_book.create_sheet()
work_sheet_solo_woman.title = "미혼녀"

# 네번째 시트 생성
work_sheet_other = work_book.create_sheet()
work_sheet_other.title = "기타"


pattern = re.compile(r" [A-Za-z]\. ")

list1 = []
for each_row in ws.iter_rows(min_row=2):

    # 이름에 패턴 적용
    data = pattern.search(each_row[3].value)
    # 제목 행
    if each_row[0].row == 1:
        for item in each_row:
            list1.append(item.value)
        work_sheet_man.append(list1)
        work_sheet_woman.append(list1)
        work_sheet_solo_woman.append(list1)
        work_sheet_other.append(list1)
    # 데이터 행
    else:
        if data != None:
            result = data.group()
            if result.strip() == "Mr. ":
                work_sheet_man.append([item.value for item in each_row])
            elif result.strip() == "Mrs. ":
                work_sheet_woman.append([item.value for item in each_row])
            elif result.strip() == "Miss. ":
                work_sheet_solo_woman.append([item.value for item in each_row])
            else:
                work_sheet_other.append([item.value for item in each_row])


work_book.save("./data/train_result.xlsx")
wb.close()
work_book.close()
